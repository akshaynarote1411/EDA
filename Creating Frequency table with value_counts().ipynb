# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns


file_path = "D:\Data Science by SRK\Omkar Sir 10.30AM Batch\EDA\Visadataset.csv"

df = pd.read_csv(file_path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df["continent"].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
df1 = pd.DataFrame(df["continent"].value_counts())
df1
# Out:
#                count
# continent
# Asia           16861
# Europe          3732
# North America   3292
# South America    852
# Africa           551
# Oceania          192

# %%
df1 = pd.DataFrame(df["continent"].value_counts()).reset_index()   # It will reset the index numbers as integer values starting from 0 
                                                                   # and the old indexes will became the columns values with column name as "index".
df1
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
cat = df.select_dtypes(include="object").columns
cat = cat.drop(cat[0])
d = pd.DataFrame()

for i in cat:
    df5 = pd.DataFrame(df[i].unique(),df[i].value_counts())
    d = pd.concat([d,df5])
    
d = d.reset_index()
d
# Out:
#     count              0
# 0   16861           Asia
# 1    3732         Africa
# 2    3292  North America
# 3     852         Europe
# 4     551  South America
# 5     192        Oceania
# 6   10234    High School
# 7    9634       Master's
# 8    3420     Bachelor's
# 9    2192      Doctorate
# 10  14802              N
# 11  10678              Y
# 12  22525              N
# 13   2955              Y
# 14   7195           West
# 15   7017      Northeast
# 16   6586          South
# 17   4307        Midwest
# 18    375         Island
# 19  22962           Hour
# 20   2157           Year
# 21    272           Week
# 22     89          Month
# 23  22773              Y
# 24   2707              N
# 25  17018         Denied
# 26   8462      Certified

# %%
d.columns = ["Counts","Labels"]
d
# Out:
#     Counts         Labels
# 0    16861           Asia
# 1     3732         Africa
# 2     3292  North America
# 3      852         Europe
# 4      551  South America
# 5      192        Oceania
# 6    10234    High School
# 7     9634       Master's
# 8     3420     Bachelor's
# 9     2192      Doctorate
# 10   14802              N
# 11   10678              Y
# 12   22525              N
# 13    2955              Y
# 14    7195           West
# 15    7017      Northeast
# 16    6586          South
# 17    4307        Midwest
# 18     375         Island
# 19   22962           Hour
# 20    2157           Year
# 21     272           Week
# 22      89          Month
# 23   22773              Y
# 24    2707              N
# 25   17018         Denied
# 26    8462      Certified
